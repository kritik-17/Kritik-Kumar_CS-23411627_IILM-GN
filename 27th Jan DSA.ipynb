# %%
#Functions
def Sum_dum(a,b,c):
    s=a+b+c
    return(s)

ans=Sum_dum(1,2,4)
print(ans)
# Out:
# 7

# %%
#scope
#local variable -- variable defined inside function
def scope():
    a=10
    print(a)
    return
scope()
# Out:
# 10

# %%
#global varibale 
b=20
def scope():
    print(b)
    return
scope()
# Out:
# 20

# %%
#global variable 
b=30
def scope():
    global b 
    b=50
scope()
print(b)
# Out:
# 50

# %%
#default parameter
def fun(a,b=20):
    return a+b
fun(10)
# Out:
# 30

# %%
def fun(a,b=20):
    return a+b
fun(10,50)
# Out:
# 60

# %%
import math 
print(math.pow(2,3))
# Out:
# 8.0

# %%
import math 
print(int(math.pow(2,3)))
# Out:
# 8

# %%
#using else in loop:
for i in range(5):
    print(i)
else:
    print("executed")
# Out:
# 0
# 1
# 2
# 3
# 4
# executed

# %%
n=int(input())
for i in range(n):
    if i==5:
        break
    print(i)
else:
    print("executed")
# Out:
#  4
# 0
# 1
# 2
# 3
# executed

# %%
n=int(input())
for i in range(n):
    if i==5:
        continue
    print(i)
else:
    print("done")
# Out:
#  7
# 0
# 1
# 2
# 3
# 4
# 6
# done

# %%
#Concatenation
var = "sweet " + "apple"
print(var)
# Out:
# sweet apple

# %%
#tuple
b=(12,13)
print(type(b))
a=(144)
print(type(a))
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
c=(1,23,45,5,67)
print(c[0:3])
# Out:
# (1, 23, 45)

# %%
print(23 not in c)
# Out:
# False

# %%
print(23 in c)
# Out:
# True

# %%
tup1=(133,1223)
tup2=(144,345)
print(tup1+tup2)
# Out:
# (133, 1223, 144, 345)

# %%
len(tup1)
# Out:
# 2

# %%
tup1.count(133)
# Out:
# 1

# %%
t=(1,23,4,56,7,789,7,23,56)
sorted(t)
# Out:
# [1, 4, 7, 7, 23, 23, 56, 56, 789]

# %%
d={a:"gaurav",b:"kritik"}
print(type(d))
d.keys()
# Out:
# <class 'dict'>
# dict_keys([144, (12, 13)])

# %%
s=input("enter the string:")
d={}
for ch in s:
    if ch in d:
        d[ch]+=1
    else:
        d[ch]=1
print(d)
# Out:
# enter the string: 45
# {'4': 1, '5': 1}

# %%
#Reoetition operation 
print(5*'a')
f=input()
n=int(input())
print(f*n)
# Out:
# aaaaa
#  kl
#  5
# klklklklkl

# %%
X= "gagan"
print(X*5)
print('*' * 10)
# Out:
# gagangagangagangagangagan
# **********

# %%
#strip
x="         gagan"
x.strip()
# Out:
# 'gagan'

# %%
j="       gaurav         "
j.lstrip()
# Out:
# 'gaurav         '

# %%
j.rstrip()
# Out:
# '       gaurav'

# %%
j.strip()
# Out:
# 'gaurav'

# %%
#replace
x="gagan"
x.replace("g","m")
# Out:
# 'maman'

# %%
#find-- it returns the index 
y="gaurav"
print(y.find("r"))
print(y.find("k"))   #if element not found , it returns -1"
# Out:
# 3
# -1

# %%
#upper & lower, isupper & islower
x="Gagan"
print(x.upper())
print(x.lower())
y="gaurav"
print(y.islower())
print(y.isupper())
# Out:
# GAGAN
# gagan
# True
# False

# %%
#Comparison Operators in strings
print("gagan"=="gagan")
print("Gagan"=="gagan")
print("gagan"!="gaurav")
print("gagan">="Gagan")
print("gagan"<="Gagan")
print("gagan"<="gagan")
print("gagan">"Gagan") #due to higher ascii value of 'g' than 'G'
# Out:
# True
# False
# True
# True
# False
# True
# True

# %%
#Membership Operator
x= "my name is Gaurav"
print("is" in x)
print("is" not in x)
# Out:
# True
# False

# %%
s=input("enter something:")
if "u" in s:
    print("valid code")
else:
    print("Invalid")
# Out:
# enter something: gaurav
# valid code

# %%
#Iterations in String
x="gaurav upadhyay"
for ch in x:
    print(ch)
# Out:
# g
# a
# u
# r
# a
# v
#
# u
# p
# a
# d
# h
# y
# a
# y

# %%
x="gagan upadhyay"
for ch in x:
    print(ch,end=' ')
# Out:
# g a g a n   u p a d h y a y

# %%
y="tantu yadav"
for i in range(len(y)):
    print(y[i])
# Out:
# t
# a
# n
# t
# u
#
# y
# a
# d
# a
# v

# %%
y="tuntun messi"
for i in range(5):
    print(y[i])
# Out:
# t
# u
# n
# t
# u

# %%
#iteration using while loop
x="gaurav"
i=0
while i<len(x):
    print(s[i])
    i+=1
# Out:
# g
# a
# u
# r
# a
# v

# %%
#reverse iteration 
x="gagan"
for i in range(len(x)-1,-1,-1):
    print(x[i])
# Out:
# n
# a
# g
# a
# g

# %%
#count vowels
x="gaurav upadhyay"
count=0
for ch in x:
    if ch.lower() in "aeiou":
        count+=1
print(count)
# Out:
# 6

# %%
z="gaurav sharma"
count=0
for ch in z:
    if ch.lower() in "aeiou":
        count+=1
print(count)
# Out:
# 5

# %%
#WAP to check or print the following Palindrome string
x=input("enter a string:")
if x==x[ : :-1]:   #reverse the string 
    print("palindrome")
else:
    print("not palidrome")
# Out:
# enter a string: neven
# palindrome

# %%
y= input("enter a string:")
rev=''
for ch in y:
    rev=ch + rev
if y==rev:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# enter a string: rever
# palindrome

# %%
#count vowels 
x= "Gaurav Upadhyay"
count=0
for ch in x:
    if ch.lower() in "aeiou":
        count+=1
print(count)
# Out:
# 6

# %%
x="gagan"
count=0
for ch in x:
    if ch.lower() in "aeiou":
        count+=1
print(count)
# Out:
# 2

# %%
x=input()
if x==x[ : :-1]:
    print("palindrome")
else:
    print("np")
# Out:
#  gauruag
# palindrome

# %%
x="gagan"
i=0
while i<len(x):
    print(x[i])
    i+=1
# Out:
# g
# a
# g
# a
# n

# %%
x='GAGAN'
for i in range(len(x)-1,-1,-1):
    print(x[i])
# Out:
# N
# A
# G
# A
# G

# %%
x="gaurav"
i=0
while i<len(x):
    print(x[i])
    i+=1
# Out:
# g
# a
# u
# r
# a
# v

# %%
#fibonacci
n=int(input("enter the range:"))
a,b=0,1
for i in range(n):
    print(a,end=' ')
    c=a+b
    a=b
    b=c
# Out:
# enter the range: 9
# 0 1 1 2 3 5 8 13 21

# %%
x=input("enter a strig:")
rev=x[ : :-1]
if x==rev:
    print("palindrome")
else:
    print("np")
# Out:
# enter a strig: gauruag
# palindrome

# %%
#fibonacci practice
x=int(input("enter a range:"))
a,b=0,1
for i in range(n):
    print(a,end=" ")
    c=a+b
    a=b
    b=c
# Out:
# enter a range: 8
# 0 1 1 2 3 5 8 13 21

# %%
x="gaurav"
i=0
while i<len(x):
    print(x[i])
    i+=1
# Out:
# g
# a
# u
# r
# a
# v

# %%
x="gagan"
for i in range (len(x)-1,-1,-1):
    print(x[i])
# Out:
# n
# a
# g
# a
# g

# %%
#factorial
x=int(input())
fact=1
for i in range(1,x+1):
    fact=fact * i
print(fact)
# Out:
#  5
# 120

# %%
x=int(input())
fact=1
for i in range(1,x+1):
    fact=fact*i
print(fact)
# Out:
#  5
# 120

# %%
n=int(input())
fact=1
for i in range(1,n+1):
    fact=fact*i
print(fact)
# Out:
#  6
# 720

# %%
#consonants
x=input("enter a string:")
count=0
for ch in x:
    if ch not in "aeiou":
        count+=1
print("no. of consonants:",count)
# Out:
# enter a string: gagan upadhyay
# no. of consonants: 9

# %%
#removing consecutive duplicates
x=input("enter string:")
res=''
for i in x:
    if res=='' or i!=res[-1]:
        res+=i
print(res)
# Out:
# enter string: helllo
# helo

# %%
#replce character 
x=input("enter the string:")
c1=input("character to be replaced:")
c2=input("enter new character:")
res=''
for ch in x:
    if ch==c1:
        res+=c2
    else:
        res+=ch
print(res)
# Out:
# enter the string: GAURAV
# character to be replaced: G
# enter new character: S
# SAURAV

# %%
#replace string
x=input("enter a string:")
c1=input("replacing character:")
c2=input("new character:")
res=''
for ch in x:
    if ch==c1:
        res+=c2
    else:
        res+=ch
print(res)
# Out:
# enter a string: gaurav
# replacing character: a
# new character: k
# gkurkv

# %%
x=input("enter string:")
res=''
for i in x:
    if res=='' or i!=res[-1]:
        res+=i
print(res)
# Out:
# enter string: ggaauurraavv
# gaurav

# %%
s=input()
words=s.split()
words.reverse()
result=' '.join(words)
print(result)
# Out:
#  gagan is good
# good is gagan

# %%
#reverse word string 
s=input()
words=s.split()
words.reverse()
res=" ".join(words)
print(res)
# Out:
#  life is family
# family is life
